# %%
import jax
from jax import numpy as np
import optax
import numpy as onp
import sys

sys.path.append('../py')
# %load_ext autoreload
# %autoreload 2
    
from tqdm.auto import tqdm
import dill as pickle

from jax import config
float_64 = False
config.update("jax_enable_x64", float_64)
if float_64:
    print('Im using float64!!!')
else:
    print('Im using float32!!!')

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.grid']           = True
mpl.rcParams['axes.grid.which']     = 'both'
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['ytick.minor.visible'] = True
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['axes.facecolor']      = 'white'
mpl.rcParams['grid.color']          = '0.8'
mpl.rcParams['text.usetex']         = True
mpl.rcParams['font.family']         = 'serif'
mpl.rcParams['figure.figsize']      = (8, 4)
mpl.rcParams['figure.titlesize']    = 7.5
mpl.rcParams['font.size']           = 10
mpl.rcParams['legend.fontsize']     = 7.5
mpl.rcParams['figure.dpi']          = 300
# Out:
# Im using float32!!!

# %% [markdown]
# ## Launch!

# %% [markdown]
# ### 64-particle cluster

# %%
# %run -i '/scratch/nb3397/projects/vicsek/py/launchers/learn.py' \
--nsteps_online 1000 \
--network_path "" \
--data_folder "/scratch/nb3397/datasets/vicsek" \
--bs 64 \
--bs_stats 256 \
--bs_online 1000 \
--visual_freq 1000 \
--save_freq 10000 \
--dt 0.01 \
--dt_online 0.01 \
--N 64 \
--v0 0.025 \
--phi 0.5 \
--A 0.0 \
--beta 75.0 \
--k 0.0 \
--gamma 0.01 \
--eps 0.0 \
--learn_sx 0 \
--network_type 'deepset_gnn' \
--translation_invariant 1 \
--n_neurons 512 \
--n_hidden 4 \
--num_transformer_layers 4 \
--num_heads 4 \
--n_neighbors 63 \
--learning_rate 0.00001 \
--decay_steps 500000 \
--loss_type "score_matching" \
--system_type "vicsek" \
--wandb_name "flax_test" \
--wandb_project "vicsek_debug_gnn" \
--output_name "flax_test" \
--output_folder "/scratch/nb3397/results/strato/debug" \
--slurm_id 0
# Out:
# loading data from /scratch/nb3397/datasets/vicsek/v0=0.025_gamma=0.01_eps=0.0_phi=0.5_dt=0.01_beta=75.0_A=0.0_k=0.0_N=64.npy
# Parameters per network: 2104834
# Finishing last run (ID:9xc15qi0) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">flax_test_0</strong> at: <a href='https://wandb.ai/boffi/vicsek_debug_gnn/runs/9xc15qi0' target="_blank">https://wandb.ai/boffi/vicsek_debug_gnn/runs/9xc15qi0</a><br/>Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240411_101512-9xc15qi0/logs</code>
# Successfully finished last run (ID:9xc15qi0). Initializing new run:<br/>
# ...
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# ...

# %% [markdown]
# ## two-particles

# %%
# %run -i '/scratch/nb3397/projects/vicsek/py/launchers/learn.py' \
--nsteps_online 1000 \
--network_path "" \
--data_folder "/scratch/nb3397/datasets/vicsek" \
--bs 10000 \
--bs_stats 10000 \
--bs_online 10000 \
--visual_freq 1000 \
--save_freq 100000 \
--dt 0.01 \
--dt_online 0.01 \
--N 2 \
--v0 0.05 \
--phi 0.25 \
--A 0.0 \
--beta 75.0 \
--k 0.0 \
--gamma 0.05 \
--eps 0.0 \
--learn_sx 0 \
--network_type 'transformer' \
--translation_invariant 1 \
--n_neurons 128 \
--n_hidden 2 \
--num_transformer_layers 4 \
--num_heads 4 \
--n_neighbors 0 \
--learning_rate 0.00001 \
--decay_steps 500000 \
--loss_type "stratonovich" \
--system_type "vicsek" \
--wandb_name "lowd_transformer_test_mlp_lower_lr" \
--wandb_project "vicsek_debug" \
--output_name "flax_test" \
--output_folder "/scratch/nb3397/results/strato/debug" \
--slurm_id 0
# Out:
# loading data from /scratch/nb3397/datasets/vicsek/v0=0.05_gamma=0.05_eps=0.0_phi=0.25_dt=0.01_beta=75.0_A=0.0_k=0.0_N=2.npy
# Parameters per network: 1437057
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: boffi. Use `wandb login --relogin` to force relogin
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/scratch/nb3397/projects/vicsek/notebooks/wandb/run-20240412_140009-16t9pnhn</code>
# Syncing run <strong><a href='https://wandb.ai/boffi/vicsek_debug/runs/16t9pnhn' target="_blank">lowd_transformer_test_mlp_lower_lr_0</a></strong> to <a href='https://wandb.ai/boffi/vicsek_debug' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...
