# %%
import functools
import importlib
import os
import sys
from typing import Callable, Dict

sys.path.append('../../py')

import click
import common.fid_utils as fid_utils
import common.flow_map as flow_map
import common.state_utils as state_utils
import common.velocity as velocity
import flax
import jax

import jax.numpy as jnp
import numpy as np
from tqdm.auto import tqdm
# Out:
# 2025-10-01 08:57:52.018399: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-01 08:57:52.067833: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759323472.083817  703815 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759323472.088593  703815 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759323472.101324  703815 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759323472.101338  703815 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759323472.101340  703815 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759323472.101341  703815 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-01 08:57:52.105427: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Tabular Visualization

# %%
import os, glob, re, numpy as np, pandas as pd

def highlight_min_per_title_column(data):
    """Highlight minimum value in each column within each title group"""
    result = pd.DataFrame('', index=data.index, columns=data.columns)
    
    # Get the title level from the index
    titles = data.index.get_level_values('title')
    
    # For each unique title
    for title in titles.unique():
        # Get rows for this title
        title_mask = titles == title
        title_data = data.loc[title_mask]
        
        # For each column (nsteps), find and highlight the minimum
        for col in data.columns:
            if title_data[col].notna().any():
                min_idx = title_data[col].idxmin()
                result.loc[min_idx, col] = 'background-color: lightblue'
    
    return result

DATA_DIR = "/n/netscratch/albergo_lab/Everyone/nmboffi/afhq64/fids"
TITLE_FILTER = ['fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30',
                'fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30',
                'fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30']

files = glob.glob(os.path.join(DATA_DIR, "*.npz"))

# Updated regex to handle new format: [title]_diag[fac]_no_anneal_[date]_ema=[ema]_N=[nsteps].npz
rx_new = re.compile(
    r"""^
        (?P<title>.+?)                  # title (non-greedy to stop at _diag)
        _diag(?P<diag_fac>\d+)         # diagonal factor
        _no_anneal                      # fixed string
        _(?P<month>\d+)                 # month
        _(?P<day>\d+)                   # day  
        _(?P<checkpoint>\d+)            # checkpoint number
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

# Original regex for backward compatibility
rx_old = re.compile(
    r"""^
        (?P<title>.+)                  # everything before checkpoint
        _(?P<checkpoint>\d+)            # last number before ema
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

records = []
for path in files:
    basename = os.path.basename(path)
    
    # Try new format first
    m = rx_new.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        # Combine title with diag_fac and date for unique identification
        rec["title"] = f"{rec['title']}_diag{rec['diag_fac']}_no_anneal_{rec['month']}_{rec['day']}"
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        rec["diag_fac"] = int(rec["diag_fac"])  # Keep diag_fac as separate field too
        
        records.append(rec)
        continue
    
    # Try old format
    m = rx_old.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        rec["diag_fac"] = None  # No diag_fac in old format
        
        records.append(rec)
        continue
    
    print("⚠️  skipped:", basename)

df = pd.DataFrame(records)
if df.empty:
    raise SystemExit("No files matched!")

# Apply title filter if specified
if TITLE_FILTER is not None:
    if isinstance(TITLE_FILTER, str):
        # Single title
        df = df[df["title"] == TITLE_FILTER]
        print(f"Filtering for title: {TITLE_FILTER}")
    elif isinstance(TITLE_FILTER, list):
        # Multiple titles
        df = df[df["title"].isin(TITLE_FILTER)]
        print(f"Filtering for titles: {TITLE_FILTER}")
    
    if df.empty:
        print("\n⚠️  No files matched the title filter!")
        print(f"Available titles: {sorted(pd.DataFrame(records)['title'].unique())}")
        raise SystemExit("No matching titles found!")

# Print summary of what we're analyzing
print(f"\nAnalyzing {len(df)} files")
print(f"Unique titles ({len(df['title'].unique())}): {sorted(df['title'].unique())}")
print(f"Checkpoint range: {df['checkpoint'].min()} - {df['checkpoint'].max()}")
print(f"EMA values: {sorted(df['ema'].unique())}")
print(f"N steps: {sorted(df['nsteps'].unique())}")
if df['diag_fac'].notna().any():
    print(f"Diag factors: {sorted(df['diag_fac'].dropna().unique())}")
print("-" * 80)

# Sort by title, ema, checkpoint, nsteps
df.sort_values(["title", "ema", "checkpoint", "nsteps"], inplace=True)

# ── wide table ───────────────────────────────────────────────────────────────
table = (
    df.pivot_table(
        index   = ["title", "ema", "checkpoint"],
        columns = "nsteps",
        values  = "fid",
        aggfunc = "first",
    )
    .reindex(sorted(df["nsteps"].unique()), axis=1)   # nice col order
    .sort_index()
)

# pretty display
with pd.option_context("display.float_format", "{:.4f}".format):
    display(
        table.style
              .highlight_min(axis=1, color="lightgreen")  # best in each row (across nsteps)
              .apply(highlight_min_per_title_column, axis=None)  # best per column per title
              .set_caption("FID (↓) by sampling steps")
    )

# ── best step per configuration ──────────────────────────────────────────────
best = (
    table.stack()
         .groupby(level=["title", "ema", "checkpoint"])
         .agg(best_nsteps = lambda s: s.idxmin()[1],   # col label (the nsteps)
              best_FID = "min")
         .reset_index()
)
print("\n=== Best FID per (title, ema, checkpoint) ===")
print(best.to_string(index=False, float_format="%.4f"))

# If multiple titles, also show best overall per title
if TITLE_FILTER is None or isinstance(TITLE_FILTER, list):
    overall_best = (
        best.groupby("title")
            .agg(best_ema = lambda s: best.loc[s.index[s.argmin()], "ema"] if "best_FID" in s.name else s.iloc[0], 
                 best_checkpoint = lambda s: best.loc[s.index[s.argmin()], "checkpoint"] if "best_FID" in s.name else s.iloc[0],
                 best_nsteps = lambda s: best.loc[s.index[s.argmin()], "best_nsteps"] if "best_FID" in s.name else s.iloc[0],
                 best_FID = "min")
            .reset_index()
    )
    print("\n=== Overall best FID per title ===")
    print(overall_best.to_string(index=False, float_format="%.4f"))
# Out:
# Filtering for titles: ['fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30', 'fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30', 'fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30']
#
# Analyzing 210 files
# Unique titles (3): ['fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30', 'fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30', 'fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30']
# Checkpoint range: 6 - 45
# EMA values: [np.float64(0.9999)]
# N steps: [np.int64(1), np.int64(2), np.int64(4), np.int64(8), np.int64(16)]
# --------------------------------------------------------------------------------
# <style type="text/css">
# #T_aaa76_row0_col4, #T_aaa76_row1_col2, #T_aaa76_row2_col3, #T_aaa76_row3_col4, #T_aaa76_row5_col4, #T_aaa76_row6_col4, #T_aaa76_row7_col4, #T_aaa76_row8_col4, #T_aaa76_row9_col4, #T_aaa76_row10_col4, #T_aaa76_row11_col4, #T_aaa76_row12_col4, #T_aaa76_row13_col4, #T_aaa76_row14_col4, #T_aaa76_row15_col4, #T_aaa76_row16_col4, #T_aaa76_row18_col4, #T_aaa76_row19_col4, #T_aaa76_row20_col4, #T_aaa76_row21_col4, #T_aaa76_row22_col4, #T_aaa76_row23_col4, #T_aaa76_row24_col4, #T_aaa76_row25_col4, #T_aaa76_row26_col4, #T_aaa76_row27_col4, #T_aaa76_row28_col2, #T_aaa76_row29_col1, #T_aaa76_row32_col2, #T_aaa76_row33_col2, #T_aaa76_row34_col4, #T_aaa76_row35_col4, #T_aaa76_row36_col4, #T_aaa76_row37_col4, #T_aaa76_row38_col4, #T_aaa76_row39_col4, #T_aaa76_row40_col4, #T_aaa76_row41_col4 {
#   background-color: lightgreen;
# }
# #T_aaa76_row2_col0, #T_aaa76_row2_col1, #T_aaa76_row3_col2, #T_aaa76_row4_col3, #T_aaa76_row15_col0, #T_aaa76_row16_col1, #T_aaa76_row17_col2, #T_aaa76_row17_col3, #T_aaa76_row29_col0, #T_aaa76_row31_col4, #T_aaa76_row32_col3 {
#   background-color: lightblue;
# }
# #T_aaa76_row4_col4, #T_aaa76_row17_col4, #T_aaa76_row30_col1, #T_aaa76_row31_col2 {
#   background-color: lightgreen;
#   background-color: lightblue;
# }
# </style>
# <table id="T_aaa76">
#   <caption>FID (↓) by sampling steps</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >nsteps</th>
#       <th id="T_aaa76_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_aaa76_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_aaa76_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_aaa76_level0_col3" class="col_heading level0 col3" >8</th>
#       <th id="T_aaa76_level0_col4" class="col_heading level0 col4" >16</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="index_name level1" >ema</th>
#       <th class="index_name level2" >checkpoint</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aaa76_level0_row0" class="row_heading level0 row0" rowspan="14">fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30</th>
#       <th id="T_aaa76_level1_row0" class="row_heading level1 row0" rowspan="14">0.999900</th>
#       <th id="T_aaa76_level2_row0" class="row_heading level2 row0" >6</th>
#       <td id="T_aaa76_row0_col0" class="data row0 col0" >18.814949</td>
#       <td id="T_aaa76_row0_col1" class="data row0 col1" >15.544588</td>
#       <td id="T_aaa76_row0_col2" class="data row0 col2" >13.834579</td>
#       <td id="T_aaa76_row0_col3" class="data row0 col3" >13.186224</td>
#       <td id="T_aaa76_row0_col4" class="data row0 col4" >12.340471</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row1" class="row_heading level2 row1" >9</th>
#       <td id="T_aaa76_row1_col0" class="data row1 col0" >12.216968</td>
#       <td id="T_aaa76_row1_col1" class="data row1 col1" >9.373468</td>
#       <td id="T_aaa76_row1_col2" class="data row1 col2" >9.113423</td>
#       <td id="T_aaa76_row1_col3" class="data row1 col3" >9.423596</td>
#       <td id="T_aaa76_row1_col4" class="data row1 col4" >9.666988</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row2" class="row_heading level2 row2" >12</th>
#       <td id="T_aaa76_row2_col0" class="data row2 col0" >11.186214</td>
#       <td id="T_aaa76_row2_col1" class="data row2 col1" >7.782547</td>
#       <td id="T_aaa76_row2_col2" class="data row2 col2" >7.057142</td>
#       <td id="T_aaa76_row2_col3" class="data row2 col3" >7.022723</td>
#       <td id="T_aaa76_row2_col4" class="data row2 col4" >7.468369</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row3" class="row_heading level2 row3" >15</th>
#       <td id="T_aaa76_row3_col0" class="data row3 col0" >13.856693</td>
#       <td id="T_aaa76_row3_col1" class="data row3 col1" >8.937778</td>
#       <td id="T_aaa76_row3_col2" class="data row3 col2" >6.995090</td>
#       <td id="T_aaa76_row3_col3" class="data row3 col3" >6.285426</td>
#       <td id="T_aaa76_row3_col4" class="data row3 col4" >6.178468</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row4" class="row_heading level2 row4" >18</th>
#       <td id="T_aaa76_row4_col0" class="data row4 col0" >16.352146</td>
#       <td id="T_aaa76_row4_col1" class="data row4 col1" >9.867768</td>
#       <td id="T_aaa76_row4_col2" class="data row4 col2" >7.052207</td>
#       <td id="T_aaa76_row4_col3" class="data row4 col3" >5.888904</td>
#       <td id="T_aaa76_row4_col4" class="data row4 col4" >5.606056</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row5" class="row_heading level2 row5" >21</th>
#       <td id="T_aaa76_row5_col0" class="data row5 col0" >20.833212</td>
#       <td id="T_aaa76_row5_col1" class="data row5 col1" >12.484217</td>
#       <td id="T_aaa76_row5_col2" class="data row5 col2" >8.620529</td>
#       <td id="T_aaa76_row5_col3" class="data row5 col3" >6.766624</td>
#       <td id="T_aaa76_row5_col4" class="data row5 col4" >5.764377</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row6" class="row_heading level2 row6" >24</th>
#       <td id="T_aaa76_row6_col0" class="data row6 col0" >24.448891</td>
#       <td id="T_aaa76_row6_col1" class="data row6 col1" >14.336191</td>
#       <td id="T_aaa76_row6_col2" class="data row6 col2" >9.731182</td>
#       <td id="T_aaa76_row6_col3" class="data row6 col3" >7.342349</td>
#       <td id="T_aaa76_row6_col4" class="data row6 col4" >6.168453</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row7" class="row_heading level2 row7" >27</th>
#       <td id="T_aaa76_row7_col0" class="data row7 col0" >26.220964</td>
#       <td id="T_aaa76_row7_col1" class="data row7 col1" >14.730128</td>
#       <td id="T_aaa76_row7_col2" class="data row7 col2" >10.130077</td>
#       <td id="T_aaa76_row7_col3" class="data row7 col3" >7.962087</td>
#       <td id="T_aaa76_row7_col4" class="data row7 col4" >6.744267</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row8" class="row_heading level2 row8" >30</th>
#       <td id="T_aaa76_row8_col0" class="data row8 col0" >28.849499</td>
#       <td id="T_aaa76_row8_col1" class="data row8 col1" >16.114891</td>
#       <td id="T_aaa76_row8_col2" class="data row8 col2" >11.272226</td>
#       <td id="T_aaa76_row8_col3" class="data row8 col3" >8.863318</td>
#       <td id="T_aaa76_row8_col4" class="data row8 col4" >7.327572</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row9" class="row_heading level2 row9" >33</th>
#       <td id="T_aaa76_row9_col0" class="data row9 col0" >31.549866</td>
#       <td id="T_aaa76_row9_col1" class="data row9 col1" >17.516140</td>
#       <td id="T_aaa76_row9_col2" class="data row9 col2" >12.423580</td>
#       <td id="T_aaa76_row9_col3" class="data row9 col3" >9.616863</td>
#       <td id="T_aaa76_row9_col4" class="data row9 col4" >7.724795</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row10" class="row_heading level2 row10" >36</th>
#       <td id="T_aaa76_row10_col0" class="data row10 col0" >33.480572</td>
#       <td id="T_aaa76_row10_col1" class="data row10 col1" >18.739334</td>
#       <td id="T_aaa76_row10_col2" class="data row10 col2" >13.561663</td>
#       <td id="T_aaa76_row10_col3" class="data row10 col3" >10.349699</td>
#       <td id="T_aaa76_row10_col4" class="data row10 col4" >8.004562</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row11" class="row_heading level2 row11" >39</th>
#       <td id="T_aaa76_row11_col0" class="data row11 col0" >35.218227</td>
#       <td id="T_aaa76_row11_col1" class="data row11 col1" >19.341242</td>
#       <td id="T_aaa76_row11_col2" class="data row11 col2" >14.145050</td>
#       <td id="T_aaa76_row11_col3" class="data row11 col3" >10.697870</td>
#       <td id="T_aaa76_row11_col4" class="data row11 col4" >8.191892</td>
#     </tr>
#     <tr>
#       <th id="T_aaa76_level2_row12" class="row_head
# === Best FID per (title, ema, checkpoint) ===
#                                                      title    ema  checkpoint  best_nsteps  best_FID
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999           6       0.9999   12.3405
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999           9       0.9999    9.1134
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          12       0.9999    7.0227
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          15       0.9999    6.1785
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          18       0.9999    5.6061
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          21       0.9999    5.7644
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          24       0.9999    6.1685
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          27       0.9999    6.7443
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          30       0.9999    7.3276
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          33       0.9999    7.7248
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          36       0.9999    8.0046
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          39       0.9999    8.1919
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          42       0.9999    8.2484
#           fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30 0.9999          45       0.9999    8.1747
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999           6       0.9999   13.3433
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999           9       0.9999   12.8570
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          12       0.9999   11.4688
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          15       0.9999   11.0691
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          18       0.9999   11.2225
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          21       0.9999   11.6529
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          24       0.9999   11.7814
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          27       0.9999   12.4727
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          30       0.9999   12.5185
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          33       0.9999   12.5818
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          36       0.9999   13.1558
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          39       0.9999   13.2768
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          42       0.9999   13.3434
# fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30 0.9999          45       0.9999   13.9283
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999           6       0.9999   14.8811
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999           9       0.9999   11.9154
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          12       0.9999   10.7329
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          15       0.9999   10.9878
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          18       0.9999   11.1895
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          21       0.9999   11.7281
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          24       0.9999   13.0158
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          27       0.9999   13.6512
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          30       0.9999   13.6716
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          33       0.9999   13.9551
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          36       0.9999   14.3262
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          39       0.9999   14.5327
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          42       0.9999   14.7771
#  fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30 0.9999          45       0.9999   14.6326
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 168
#     164 # If multiple titles, also show best overall per title
#     165 if TITLE_FILTER is None or isinstance(TITLE_FILTER, list):
#     166     overall_best = (
#     167         best.groupby("title")
# --> 168             .agg(best_ema = lambda s: best.loc[s.index[s.argmin()], "ema"] if "best_FID" in s.name else s.iloc[0],
#     169                  best_checkpoint = lambda s: best.loc[s.index[s.argmin()], "checkpoint"] if "best_FID" in s.name else s.iloc[0],
#     170                  best_nsteps = lambda s: best.loc[s.index[s.argmin()], "best_nsteps"] if "best_FID" in s.name else s.iloc[0],
#     171                  best_FID = "min")
#     172             .reset_index()
#     173     )
#     174     print("\n=== Overall best FID per title ===")
#     175     print(overall_best.to_string(index=False, float_format="%.4f"))
#
# File ~/.conda/envs/jax_3_17_25/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1422, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1420 @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1421 def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1422     relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1423     func = maybe_mangle_lambdas(func)
#    1425     if maybe_use_numba(engine):
#    1426         # Not all agg functions support numba, only propagate numba kwargs
#    1427         # if user asks for numba
#
# File ~/.conda/envs/jax_3_17_25/lib/python3.12/site-packages/pandas/core/apply.py:1696, in reconstruct_func(func, **kwargs)
#    1690         raise SpecificationError(
#    1691             "Function names must be unique if there is no new column names "
#    1692             "assigned"
#    1693         )
#    1694     if func is None:
#    1695         # nicer error message
# -> 1696         raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1698 if relabeling:
#    1699     # error: Incompatible types in assignment (expression has type
#    1700     # "MutableMapping[Hashable, list[Callable[..., Any] | str]]", variable has type
#    1701     # "Callable[..., Any] | str | list[Callable[..., Any] | str] |
#    1702     # MutableMapping[Hashable, Callable[..., Any] | str | list[Callable[..., Any] |
#    1703     # str]] | None")
#    1704     func, columns, order = normalize_keyword_aggregation(  # type: ignore[assignment]
#    1705         kwargs
#    1706     )
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %% [markdown]
# # Optimal Sampling

# %%
import os, functools, importlib, jax, jax.numpy as jnp, numpy as np
import pandas as pd, glob, re
from matplotlib import pyplot as plt
import flax

plt.rcParams['text.usetex'] = False

# ==================== Configuration ====================
model_folder = "/n/netscratch/albergo_lab/Everyone/nmboffi/afhq64"
fid_results_path = "/n/netscratch/albergo_lab/Everyone/nmboffi/afhq64/fids"

# Map FID title prefixes to model configuration
TITLE_TO_CONFIG = {
    'fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30': {
        'base_name': 'afhq64_lsd_stopgrad_convex_diag75_bs256_9_30',
        'slurm_id': 0,
        'cfg_module': 'configs.9_30_25_afhq64_loss_comparison',
        'label': 'LSD'
    },
    'fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30': {
        'base_name': 'afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30',
        'slurm_id': 2,
        'cfg_module': 'configs.9_30_25_afhq64_loss_comparison',
        'label': 'PSD-M'
    },
    'fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30': {
        'base_name': 'afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30',
        'slurm_id': 1,
        'cfg_module': 'configs.9_30_25_afhq64_loss_comparison',
        'label': 'PSD-U'
    }
}

N_STEPS = [1, 2, 4, 8, 16]
N_SHOW = 8
SEED = 10

# ==================== Load FID Results ====================
files = glob.glob(os.path.join(fid_results_path, "*.npz"))

# Use OLD format regex (no diag/date suffix)
rx_old = re.compile(
    r"""^
        (?P<title>.+)                  # everything before checkpoint
        _(?P<checkpoint>\d+)            # last number before ema
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

records = []
for path in files:
    basename = os.path.basename(path)
    m = rx_old.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        records.append(rec)

df = pd.DataFrame(records)

print(f"Loaded {len(df)} FID records")
print(f"Unique titles: {df['title'].unique()}")

# Find best checkpoint for each (title, nsteps) combination
best_checkpoints = {}
for title, config in TITLE_TO_CONFIG.items():
    title_df = df[df['title'] == title]
    
    if len(title_df) == 0:
        print(f"⚠️  No data found for {title}")
        continue
    
    best_checkpoints[title] = {}
    
    print(f"\n{config['label']} ({title}):")
    for n in N_STEPS:
        n_df = title_df[title_df['nsteps'] == n]
        if len(n_df) > 0:
            best_idx = n_df['fid'].idxmin()
            best_row = n_df.loc[best_idx]
            best_checkpoints[title][n] = {
                'checkpoint': int(best_row['checkpoint']),
                'ema': float(best_row['ema']),
                'fid': float(best_row['fid'])
            }
            print(f"  N={n:2d} → checkpoint {best_row['checkpoint']:3d}, "
                  f"ema={best_row['ema']}, FID={best_row['fid']:.3f}")

# ==================== Sampling Functions ====================
def make_grid(imgs, n_cols=N_SHOW):
    B, H, W, C = imgs.shape
    n_rows = (B + n_cols - 1) // n_cols
    canvas = np.ones((n_rows*H, n_cols*W, C), dtype=imgs.dtype)
    for idx, im in enumerate(imgs):
        r, c = divmod(idx, n_cols)
        canvas[r*H:(r+1)*H, c*W:(c+1)*W] = im
    return canvas

def define_sampler(cfg: Dict) -> Callable:
    return flow_map.batch_sample

def sample_single_n(ckpt_path, ema, slurm_id, cfg_module, x0s, n_steps):
    """Sample with a specific checkpoint for a specific number of steps"""
    cfg = importlib.import_module(cfg_module).get_config(slurm_id, "", "")
    if cfg.problem.gaussian_scale == "adaptive":
        cfg.network.rescale = 0.5 if cfg.problem.target in {"mnist", "cifar10", "celeb_a"} or "afhq" in cfg.problem.target else 1.0
    
    sampler_fn = define_sampler(cfg)
    
    # Initialize network
    net, params, _ = (
        velocity.initialize_velocity
        if cfg.training.train_velocity else flow_map.initialize_flow_map
    )(cfg.network, jnp.zeros(cfg.problem.image_dims), jax.random.PRNGKey(SEED))
    
    # Load checkpoint
    with open(ckpt_path, "rb") as f:
        dummy_tx, _ = state_utils.setup_optimizer(cfg)
        ts = state_utils.EMATrainState.create(
            apply_fn=net.apply, params=params, ema_params={ema: params}, tx=dummy_tx
        )
        ts = flax.serialization.from_bytes(ts, f.read())
    
    params = ts.ema_params[ema] if ema else ts.params
    
    # Sample
    imgs = sampler_fn(net.apply, params, x0s, n_steps, None)
    imgs = ((jnp.clip(imgs, -1, 1).transpose(0, 2, 3, 1) + 1) / 2).astype(np.float32)
    return make_grid(np.asarray(imgs))

# ==================== Generate Samples ====================
@functools.partial(jax.jit, static_argnums=(0,))
def sample_rho0(bs, key):
    return 0.5 * jax.random.normal(key, (bs, 3, 64, 64))

key = jax.random.PRNGKey(SEED)
x0s = sample_rho0(N_SHOW, key)

# Sample and visualize for each method
for title, config in TITLE_TO_CONFIG.items():
    if title not in best_checkpoints:
        print(f"⚠️  No checkpoints found for {title}")
        continue
    
    print(f"\n{'='*60}\nSampling {config['label']}\n{'='*60}")
    
    grids = []
    for n in N_STEPS:
        if n not in best_checkpoints[title]:
            print(f"⚠️  No checkpoint for N={n}, skipping")
            continue
        
        best = best_checkpoints[title][n]
        ckpt_path = f"{model_folder}/{config['base_name']}_{best['checkpoint']}.pkl"
        
        print(f"N={n:2d}: Loading checkpoint {best['checkpoint']:3d} (FID={best['fid']:.3f})")
        
        grid = sample_single_n(
            ckpt_path, 
            best['ema'], 
            config['slurm_id'], 
            config['cfg_module'], 
            x0s, 
            n
        )
        grids.append(grid)
    
    # Create visualization
    n_rows = len(grids)
    fig, axes = plt.subplots(
        n_rows, 1,
        figsize=(N_SHOW*1.6, n_rows*1.6),
        dpi=160,
        tight_layout=True
    )
    if n_rows == 1:
        axes = [axes]
    
    for ax, grid, n in zip(axes, grids, N_STEPS[:len(grids)]):
        ax.imshow(grid)
        ax.set_xticks([]); ax.set_yticks([]); ax.set_xlabel("")
        for spine in ("top", "right", "bottom"):
            ax.spines[spine].set_visible(False)
    
    # Save
    out_name = f"plots/afhq64_{config['label'].replace(' ', '_')}_best.png"
    fig.savefig(out_name, dpi=160, bbox_inches="tight")
    print(f"✓ Saved → {out_name}")
    plt.show()

print("\n✓ Done!")
# Out:
# Loaded 210 FID records
# Unique titles: ['fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30'
#  'fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30'
#  'fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30']
#
# LSD (fid_afhq64_lsd_stopgrad_convex_diag75_bs256_9_30):
#   N= 1 → checkpoint  12, ema=0.9999, FID=11.186
#   N= 2 → checkpoint  12, ema=0.9999, FID=7.783
#   N= 4 → checkpoint  15, ema=0.9999, FID=6.995
#   N= 8 → checkpoint  18, ema=0.9999, FID=5.889
#   N=16 → checkpoint  18, ema=0.9999, FID=5.606
#
# PSD-M (fid_afhq64_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_30):
#   N= 1 → checkpoint   9, ema=0.9999, FID=18.858
#   N= 2 → checkpoint  12, ema=0.9999, FID=14.751
#   N= 4 → checkpoint  15, ema=0.9999, FID=14.397
#   N= 8 → checkpoint  15, ema=0.9999, FID=13.262
#   N=16 → checkpoint  15, ema=0.9999, FID=11.069
#
# PSD-U (fid_afhq64_pfmm_uniform_stopgrad_convex_diag75_bs256_9_30):
#   N= 1 → checkpoint   9, ema=0.9999, FID=14.502
#   N= 2 → checkpoint  12, ema=0.9999, FID=10.733
#   N= 4 → checkpoint  15, ema=0.9999, FID=10.988
#   N= 8 → checkpoint  18, ema=0.9999, FID=12.018
#   N=16 → checkpoint  15, ema=0.9999, FID=11.465
#
# ============================================================
# Sampling LSD
# ============================================================
# N= 1: Loading checkpoint  12 (FID=11.186)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  12 (FID=7.783)
# Number of parameters: 124264485
# N= 4: Loading checkpoint  15 (FID=6.995)
# Number of parameters: 124264485
# N= 8: Loading checkpoint  18 (FID=5.889)
# Number of parameters: 124264485
# N=16: Loading checkpoint  18 (FID=5.606)
# Number of parameters: 124264485
# ✓ Saved → plots/afhq64_LSD_best.png
# ============================================================
# Sampling PSD-M
# ============================================================
# N= 1: Loading checkpoint   9 (FID=18.858)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  12 (FID=14.751)
# Number of parameters: 124264485
# N= 4: Loading checkpoint  15 (FID=14.397)
# Number of parameters: 124264485
# N= 8: Loading checkpoint  15 (FID=13.262)
# Number of parameters: 124264485
# N=16: Loading checkpoint  15 (FID=11.069)
# Number of parameters: 124264485
# ✓ Saved → plots/afhq64_PSD-M_best.png
# ============================================================
# Sampling PSD-U
# ============================================================
# N= 1: Loading checkpoint   9 (FID=14.502)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  12 (FID=10.733)
# Number of parameters: 124264485
# N= 4: Loading checkpoint  15 (FID=10.988)
# Number of parameters: 124264485
# N= 8: Loading checkpoint  18 (FID=12.018)
# Number of parameters: 124264485
# N=16: Loading checkpoint  15 (FID=11.465)
# Number of parameters: 124264485
# ✓ Saved → plots/afhq64_PSD-U_best.png
# ✓ Done!
