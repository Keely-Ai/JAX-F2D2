# %%
import functools
import importlib
import os
import sys
from typing import Callable, Dict

sys.path.append('../../py')

import click
import common.fid_utils as fid_utils
import common.flow_map as flow_map
import common.state_utils as state_utils
import common.velocity as velocity
import flax
import jax
import jax.numpy as jnp
import numpy as np
from tqdm.auto import tqdm
# Out:
# 2025-09-30 15:35:35.698625: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-30 15:35:35.753365: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759260935.769122 2586855 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759260935.773875 2586855 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759260935.786670 2586855 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759260935.786686 2586855 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759260935.786687 2586855 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759260935.786689 2586855 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-30 15:35:35.790754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Tabular Visualization

# %%
import os, glob, re, numpy as np, pandas as pd

def highlight_min_per_title_column(data):
    """Highlight minimum value in each column within each title group"""
    result = pd.DataFrame('', index=data.index, columns=data.columns)
    
    # Get the title level from the index
    titles = data.index.get_level_values('title')
    
    # For each unique title
    for title in titles.unique():
        # Get rows for this title
        title_mask = titles == title
        title_data = data.loc[title_mask]
        
        # For each column (nsteps), find and highlight the minimum
        for col in data.columns:
            if title_data[col].notna().any():
                min_idx = title_data[col].idxmin()
                result.loc[min_idx, col] = 'background-color: lightblue'
    
    return result

DATA_DIR = "/n/netscratch/albergo_lab/Everyone/nmboffi/celeba/fids"
TITLE_FILTER = ['fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed',
                'fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed',
                'fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed']

files = glob.glob(os.path.join(DATA_DIR, "*.npz"))

# Updated regex to handle new format: [title]_diag[fac]_no_anneal_[date]_ema=[ema]_N=[nsteps].npz
rx_new = re.compile(
    r"""^
        (?P<title>.+?)                  # title (non-greedy to stop at _diag)
        _diag(?P<diag_fac>\d+)         # diagonal factor
        _no_anneal                      # fixed string
        _(?P<month>\d+)                 # month
        _(?P<day>\d+)                   # day  
        _(?P<checkpoint>\d+)            # checkpoint number
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

# Original regex for backward compatibility
rx_old = re.compile(
    r"""^
        (?P<title>.+)                  # everything before checkpoint
        _(?P<checkpoint>\d+)            # last number before ema
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

records = []
for path in files:
    basename = os.path.basename(path)
    
    # Try new format first
    m = rx_new.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        # Combine title with diag_fac and date for unique identification
        rec["title"] = f"{rec['title']}_diag{rec['diag_fac']}_no_anneal_{rec['month']}_{rec['day']}"
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        rec["diag_fac"] = int(rec["diag_fac"])  # Keep diag_fac as separate field too
        
        records.append(rec)
        continue
    
    # Try old format
    m = rx_old.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        rec["diag_fac"] = None  # No diag_fac in old format
        
        records.append(rec)
        continue
    
    print("⚠️  skipped:", basename)

df = pd.DataFrame(records)
if df.empty:
    raise SystemExit("No files matched!")

# Apply title filter if specified
if TITLE_FILTER is not None:
    if isinstance(TITLE_FILTER, str):
        # Single title
        df = df[df["title"] == TITLE_FILTER]
        print(f"Filtering for title: {TITLE_FILTER}")
    elif isinstance(TITLE_FILTER, list):
        # Multiple titles
        df = df[df["title"].isin(TITLE_FILTER)]
        print(f"Filtering for titles: {TITLE_FILTER}")
    
    if df.empty:
        print("\n⚠️  No files matched the title filter!")
        print(f"Available titles: {sorted(pd.DataFrame(records)['title'].unique())}")
        raise SystemExit("No matching titles found!")

# Print summary of what we're analyzing
print(f"\nAnalyzing {len(df)} files")
print(f"Unique titles ({len(df['title'].unique())}): {sorted(df['title'].unique())}")
print(f"Checkpoint range: {df['checkpoint'].min()} - {df['checkpoint'].max()}")
print(f"EMA values: {sorted(df['ema'].unique())}")
print(f"N steps: {sorted(df['nsteps'].unique())}")
if df['diag_fac'].notna().any():
    print(f"Diag factors: {sorted(df['diag_fac'].dropna().unique())}")
print("-" * 80)

# Sort by title, ema, checkpoint, nsteps
df.sort_values(["title", "ema", "checkpoint", "nsteps"], inplace=True)

# ── wide table ───────────────────────────────────────────────────────────────
table = (
    df.pivot_table(
        index   = ["title", "ema", "checkpoint"],
        columns = "nsteps",
        values  = "fid",
        aggfunc = "first",
    )
    .reindex(sorted(df["nsteps"].unique()), axis=1)   # nice col order
    .sort_index()
)

# pretty display
with pd.option_context("display.float_format", "{:.4f}".format):
    display(
        table.style
              .highlight_min(axis=1, color="lightgreen")  # best in each row (across nsteps)
              .apply(highlight_min_per_title_column, axis=None)  # best per column per title
              .set_caption("FID (↓) by sampling steps")
    )

# ── best step per configuration ──────────────────────────────────────────────
best = (
    table.stack()
         .groupby(level=["title", "ema", "checkpoint"])
         .agg(best_nsteps = lambda s: s.idxmin()[1],   # col label (the nsteps)
              best_FID = "min")
         .reset_index()
)
print("\n=== Best FID per (title, ema, checkpoint) ===")
print(best.to_string(index=False, float_format="%.4f"))

# If multiple titles, also show best overall per title
if TITLE_FILTER is None or isinstance(TITLE_FILTER, list):
    overall_best = (
        best.groupby("title")
            .agg(best_ema = lambda s: best.loc[s.index[s.argmin()], "ema"] if "best_FID" in s.name else s.iloc[0], 
                 best_checkpoint = lambda s: best.loc[s.index[s.argmin()], "checkpoint"] if "best_FID" in s.name else s.iloc[0],
                 best_nsteps = lambda s: best.loc[s.index[s.argmin()], "best_nsteps"] if "best_FID" in s.name else s.iloc[0],
                 best_FID = "min")
            .reset_index()
    )
    print("\n=== Overall best FID per title ===")
    print(overall_best.to_string(index=False, float_format="%.4f"))
# Out:
# Filtering for titles: ['fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed', 'fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed', 'fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed']
#
# Analyzing 300 files
# Unique titles (3): ['fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed', 'fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed', 'fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed']
# Checkpoint range: 35 - 130
# EMA values: [np.float64(0.9999)]
# N steps: [np.int64(1), np.int64(2), np.int64(4), np.int64(8), np.int64(16)]
# --------------------------------------------------------------------------------
# <style type="text/css">
# #T_c835b_row0_col3, #T_c835b_row1_col3, #T_c835b_row2_col4, #T_c835b_row3_col4, #T_c835b_row4_col4, #T_c835b_row5_col4, #T_c835b_row6_col4, #T_c835b_row7_col4, #T_c835b_row8_col4, #T_c835b_row9_col4, #T_c835b_row10_col4, #T_c835b_row11_col4, #T_c835b_row13_col4, #T_c835b_row14_col4, #T_c835b_row15_col4, #T_c835b_row16_col4, #T_c835b_row17_col4, #T_c835b_row18_col4, #T_c835b_row19_col4, #T_c835b_row20_col4, #T_c835b_row21_col4, #T_c835b_row22_col4, #T_c835b_row23_col4, #T_c835b_row24_col4, #T_c835b_row25_col4, #T_c835b_row26_col4, #T_c835b_row27_col4, #T_c835b_row28_col4, #T_c835b_row29_col4, #T_c835b_row30_col4, #T_c835b_row31_col4, #T_c835b_row32_col4, #T_c835b_row33_col4, #T_c835b_row34_col4, #T_c835b_row35_col4, #T_c835b_row36_col4, #T_c835b_row38_col4, #T_c835b_row39_col4, #T_c835b_row40_col4, #T_c835b_row41_col3, #T_c835b_row42_col3, #T_c835b_row43_col3, #T_c835b_row44_col3, #T_c835b_row45_col3, #T_c835b_row46_col4, #T_c835b_row47_col4, #T_c835b_row48_col4, #T_c835b_row49_col4, #T_c835b_row50_col4, #T_c835b_row51_col4, #T_c835b_row52_col4, #T_c835b_row53_col4, #T_c835b_row54_col4, #T_c835b_row55_col4, #T_c835b_row56_col4, #T_c835b_row57_col4, #T_c835b_row59_col4 {
#   background-color: lightgreen;
# }
# #T_c835b_row6_col1, #T_c835b_row17_col0, #T_c835b_row17_col2, #T_c835b_row17_col3, #T_c835b_row30_col1, #T_c835b_row31_col0, #T_c835b_row37_col2, #T_c835b_row37_col3, #T_c835b_row49_col3, #T_c835b_row50_col0, #T_c835b_row50_col1, #T_c835b_row50_col2 {
#   background-color: lightblue;
# }
# #T_c835b_row12_col4, #T_c835b_row37_col4, #T_c835b_row58_col4 {
#   background-color: lightgreen;
#   background-color: lightblue;
# }
# </style>
# <table id="T_c835b">
#   <caption>FID (↓) by sampling steps</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >nsteps</th>
#       <th id="T_c835b_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c835b_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c835b_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_c835b_level0_col3" class="col_heading level0 col3" >8</th>
#       <th id="T_c835b_level0_col4" class="col_heading level0 col4" >16</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >title</th>
#       <th class="index_name level1" >ema</th>
#       <th class="index_name level2" >checkpoint</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c835b_level0_row0" class="row_heading level0 row0" rowspan="20">fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed</th>
#       <th id="T_c835b_level1_row0" class="row_heading level1 row0" rowspan="20">0.999900</th>
#       <th id="T_c835b_level2_row0" class="row_heading level2 row0" >35</th>
#       <td id="T_c835b_row0_col0" class="data row0 col0" >14.942053</td>
#       <td id="T_c835b_row0_col1" class="data row0 col1" >6.981862</td>
#       <td id="T_c835b_row0_col2" class="data row0 col2" >4.324103</td>
#       <td id="T_c835b_row0_col3" class="data row0 col3" >3.493299</td>
#       <td id="T_c835b_row0_col4" class="data row0 col4" >3.524344</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row1" class="row_heading level2 row1" >40</th>
#       <td id="T_c835b_row1_col0" class="data row1 col0" >13.874292</td>
#       <td id="T_c835b_row1_col1" class="data row1 col1" >6.242251</td>
#       <td id="T_c835b_row1_col2" class="data row1 col2" >3.719383</td>
#       <td id="T_c835b_row1_col3" class="data row1 col3" >2.924887</td>
#       <td id="T_c835b_row1_col4" class="data row1 col4" >2.990255</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row2" class="row_heading level2 row2" >45</th>
#       <td id="T_c835b_row2_col0" class="data row2 col0" >13.614078</td>
#       <td id="T_c835b_row2_col1" class="data row2 col1" >6.206316</td>
#       <td id="T_c835b_row2_col2" class="data row2 col2" >3.605968</td>
#       <td id="T_c835b_row2_col3" class="data row2 col3" >2.789170</td>
#       <td id="T_c835b_row2_col4" class="data row2 col4" >2.768610</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row3" class="row_heading level2 row3" >50</th>
#       <td id="T_c835b_row3_col0" class="data row3 col0" >13.788442</td>
#       <td id="T_c835b_row3_col1" class="data row3 col1" >6.477998</td>
#       <td id="T_c835b_row3_col2" class="data row3 col2" >3.805896</td>
#       <td id="T_c835b_row3_col3" class="data row3 col3" >2.882392</td>
#       <td id="T_c835b_row3_col4" class="data row3 col4" >2.766115</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row4" class="row_heading level2 row4" >55</th>
#       <td id="T_c835b_row4_col0" class="data row4 col0" >12.965021</td>
#       <td id="T_c835b_row4_col1" class="data row4 col1" >5.939106</td>
#       <td id="T_c835b_row4_col2" class="data row4 col2" >3.371501</td>
#       <td id="T_c835b_row4_col3" class="data row4 col3" >2.529622</td>
#       <td id="T_c835b_row4_col4" class="data row4 col4" >2.504063</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row5" class="row_heading level2 row5" >60</th>
#       <td id="T_c835b_row5_col0" class="data row5 col0" >12.569447</td>
#       <td id="T_c835b_row5_col1" class="data row5 col1" >5.851898</td>
#       <td id="T_c835b_row5_col2" class="data row5 col2" >3.372235</td>
#       <td id="T_c835b_row5_col3" class="data row5 col3" >2.528913</td>
#       <td id="T_c835b_row5_col4" class="data row5 col4" >2.445880</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row6" class="row_heading level2 row6" >65</th>
#       <td id="T_c835b_row6_col0" class="data row6 col0" >12.583747</td>
#       <td id="T_c835b_row6_col1" class="data row6 col1" >5.736722</td>
#       <td id="T_c835b_row6_col2" class="data row6 col2" >3.221334</td>
#       <td id="T_c835b_row6_col3" class="data row6 col3" >2.366979</td>
#       <td id="T_c835b_row6_col4" class="data row6 col4" >2.301165</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row7" class="row_heading level2 row7" >70</th>
#       <td id="T_c835b_row7_col0" class="data row7 col0" >12.731001</td>
#       <td id="T_c835b_row7_col1" class="data row7 col1" >5.928304</td>
#       <td id="T_c835b_row7_col2" class="data row7 col2" >3.369423</td>
#       <td id="T_c835b_row7_col3" class="data row7 col3" >2.464322</td>
#       <td id="T_c835b_row7_col4" class="data row7 col4" >2.316585</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row8" class="row_heading level2 row8" >75</th>
#       <td id="T_c835b_row8_col0" class="data row8 col0" >12.598473</td>
#       <td id="T_c835b_row8_col1" class="data row8 col1" >5.947620</td>
#       <td id="T_c835b_row8_col2" class="data row8 col2" >3.418895</td>
#       <td id="T_c835b_row8_col3" class="data row8 col3" >2.449765</td>
#       <td id="T_c835b_row8_col4" class="data row8 col4" >2.219594</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row9" class="row_heading level2 row9" >80</th>
#       <td id="T_c835b_row9_col0" class="data row9 col0" >12.591660</td>
#       <td id="T_c835b_row9_col1" class="data row9 col1" >5.809746</td>
#       <td id="T_c835b_row9_col2" class="data row9 col2" >3.209718</td>
#       <td id="T_c835b_row9_col3" class="data row9 col3" >2.259626</td>
#       <td id="T_c835b_row9_col4" class="data row9 col4" >2.074123</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row10" class="row_heading level2 row10" >85</th>
#       <td id="T_c835b_row10_col0" class="data row10 col0" >12.235826</td>
#       <td id="T_c835b_row10_col1" class="data row10 col1" >5.820225</td>
#       <td id="T_c835b_row10_col2" class="data row10 col2" >3.335950</td>
#       <td id="T_c835b_row10_col3" class="data row10 col3" >2.398551</td>
#       <td id="T_c835b_row10_col4" class="data row10 col4" >2.185148</td>
#     </tr>
#     <tr>
#       <th id="T_c835b_level2_row11" class="row_heading level2 row11" >90</th>
#       <td id="T_c835b_row11_col0" class="da
# === Best FID per (title, ema, checkpoint) ===
#                                                             title    ema  checkpoint  best_nsteps  best_FID
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          35       0.9999    3.4933
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          40       0.9999    2.9249
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          45       0.9999    2.7686
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          50       0.9999    2.7661
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          55       0.9999    2.5041
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          60       0.9999    2.4459
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          65       0.9999    2.3012
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          70       0.9999    2.3166
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          75       0.9999    2.2196
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          80       0.9999    2.0741
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          85       0.9999    2.1851
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          90       0.9999    2.0357
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          95       0.9999    1.9642
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         100       0.9999    2.0565
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         105       0.9999    2.0884
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         110       0.9999    2.0483
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         115       0.9999    1.9881
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         120       0.9999    1.9836
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         125       0.9999    2.0558
#           fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         130       0.9999    2.0227
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          35       0.9999    7.7333
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          40       0.9999    7.3741
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          45       0.9999    6.9265
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          50       0.9999    7.0629
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          55       0.9999    6.6758
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          60       0.9999    6.3812
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          65       0.9999    6.0935
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          70       0.9999    5.8726
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          75       0.9999    5.8058
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          80       0.9999    5.7083
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          85       0.9999    5.3665
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          90       0.9999    5.2879
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          95       0.9999    5.4397
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         100       0.9999    5.3932
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         105       0.9999    5.4354
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         110       0.9999    5.4055
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         115       0.9999    5.4041
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         120       0.9999    5.0931
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         125       0.9999    5.2824
# fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         130       0.9999    5.3601
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          35       0.9999    8.0664
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          40       0.9999    7.6347
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          45       0.9999    7.2410
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          50       0.9999    7.0273
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          55       0.9999    6.7559
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          60       0.9999    6.6658
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          65       0.9999    6.1921
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          70       0.9999    5.9671
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          75       0.9999    5.9483
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          80       0.9999    5.9111
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          85       0.9999    5.9332
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          90       0.9999    5.9526
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999          95       0.9999    5.9050
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         100       0.9999    5.8339
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         105       0.9999    5.8844
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         110       0.9999    6.0103
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         115       0.9999    5.8562
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         120       0.9999    5.8934
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         125       0.9999    5.6266
#  fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed 0.9999         130       0.9999    5.6830
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 168
#     164 # If multiple titles, also show best overall per title
#     165 if TITLE_FILTER is None or isinstance(TITLE_FILTER, list):
#     166     overall_best = (
#     167         best.groupby("title")
# --> 168             .agg(best_ema = lambda s: best.loc[s.index[s.argmin()], "ema"] if "best_FID" in s.name else s.iloc[0],
#     169                  best_checkpoint = lambda s: best.loc[s.index[s.argmin()], "checkpoint"] if "best_FID" in s.name else s.iloc[0],
#     170                  best_nsteps = lambda s: best.loc[s.index[s.argmin()], "best_nsteps"] if "best_FID" in s.name else s.iloc[0],
#     171                  best_FID = "min")
#     172             .reset_index()
#     173     )
#     174     print("\n=== Overall best FID per title ===")
#     175     print(overall_best.to_string(index=False, float_format="%.4f"))
#
# File ~/.conda/envs/jax_3_17_25/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1422, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1420 @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1421 def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1422     relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1423     func = maybe_mangle_lambdas(func)
#    1425     if maybe_use_numba(engine):
#    1426         # Not all agg functions support numba, only propagate numba kwargs
#    1427         # if user asks for numba
#
# File ~/.conda/envs/jax_3_17_25/lib/python3.12/site-packages/pandas/core/apply.py:1696, in reconstruct_func(func, **kwargs)
#    1690         raise SpecificationError(
#    1691             "Function names must be unique if there is no new column names "
#    1692             "assigned"
#    1693         )
#    1694     if func is None:
#    1695         # nicer error message
# -> 1696         raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1698 if relabeling:
#    1699     # error: Incompatible types in assignment (expression has type
#    1700     # "MutableMapping[Hashable, list[Callable[..., Any] | str]]", variable has type
#    1701     # "Callable[..., Any] | str | list[Callable[..., Any] | str] |
#    1702     # MutableMapping[Hashable, Callable[..., Any] | str | list[Callable[..., Any] |
#    1703     # str]] | None")
#    1704     func, columns, order = normalize_keyword_aggregation(  # type: ignore[assignment]
#    1705         kwargs
#    1706     )
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %% [markdown]
# # Optimal Sampling

# %%
import os, functools, importlib, jax, jax.numpy as jnp, numpy as np
import pandas as pd, glob, re
from matplotlib import pyplot as plt
import flax

plt.rcParams['text.usetex'] = False

# ==================== Configuration ====================
model_folder = "/n/netscratch/albergo_lab/Everyone/nmboffi/celeba"
fid_results_path = "/n/netscratch/albergo_lab/Everyone/nmboffi/celeba/fids"

# Map FID title prefixes to model configuration
TITLE_TO_CONFIG = {
    'fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed': {
        'base_name': 'celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed',
        'slurm_id': 0,
        'cfg_module': 'configs.9_8_25_celeba_loss_method_resume',
        'label': 'LSD'
    },
    'fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed': {
        'base_name': 'celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed',
        'slurm_id': 2,
        'cfg_module': 'configs.9_8_25_celeba_loss_method_resume',
        'label': 'PSD-M'
    },
    'fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed': {
        'base_name': 'celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed',
        'slurm_id': 1,
        'cfg_module': 'configs.9_8_25_celeba_loss_method_resume',
        'label': 'PSD-U'
    }
}

N_STEPS = [1, 2, 4, 8, 16]
N_SHOW = 8
SEED = 32

# ==================== Load FID Results ====================
files = glob.glob(os.path.join(fid_results_path, "*.npz"))

# Use OLD format regex (no diag/date suffix)
rx_old = re.compile(
    r"""^
        (?P<title>.+)                  # everything before checkpoint
        _(?P<checkpoint>\d+)            # last number before ema
        _ema=(?P<ema>[0-9.]+)          # ema value
        _N=(?P<nsteps>\d+)             # N value
        \.npz$                         # extension
    """,
    re.VERBOSE,
)

records = []
for path in files:
    basename = os.path.basename(path)
    m = rx_old.match(basename)
    if m:
        with np.load(path) as z:
            fid = float(z["fid"])
        
        rec = m.groupdict()
        rec["checkpoint"] = int(rec["checkpoint"])
        rec["ema"] = float(rec["ema"])
        rec["nsteps"] = int(rec["nsteps"])
        rec["fid"] = fid
        records.append(rec)

df = pd.DataFrame(records)

print(f"Loaded {len(df)} FID records")
print(f"Unique titles: {df['title'].unique()}")

# Find best checkpoint for each (title, nsteps) combination
best_checkpoints = {}
for title, config in TITLE_TO_CONFIG.items():
    title_df = df[df['title'] == title]
    
    if len(title_df) == 0:
        print(f"⚠️  No data found for {title}")
        continue
    
    best_checkpoints[title] = {}
    
    print(f"\n{config['label']} ({title}):")
    for n in N_STEPS:
        n_df = title_df[title_df['nsteps'] == n]
        if len(n_df) > 0:
            best_idx = n_df['fid'].idxmin()
            best_row = n_df.loc[best_idx]
            best_checkpoints[title][n] = {
                'checkpoint': int(best_row['checkpoint']),
                'ema': float(best_row['ema']),
                'fid': float(best_row['fid'])
            }
            print(f"  N={n:2d} → checkpoint {best_row['checkpoint']:3d}, "
                  f"ema={best_row['ema']}, FID={best_row['fid']:.3f}")

# ==================== Sampling Functions ====================
def make_grid(imgs, n_cols=N_SHOW):
    B, H, W, C = imgs.shape
    n_rows = (B + n_cols - 1) // n_cols
    canvas = np.ones((n_rows*H, n_cols*W, C), dtype=imgs.dtype)
    for idx, im in enumerate(imgs):
        r, c = divmod(idx, n_cols)
        canvas[r*H:(r+1)*H, c*W:(c+1)*W] = im
    return canvas

def define_sampler(cfg: Dict) -> Callable:
    return flow_map.batch_sample

def sample_single_n(ckpt_path, ema, slurm_id, cfg_module, x0s, n_steps):
    """Sample with a specific checkpoint for a specific number of steps"""
    cfg = importlib.import_module(cfg_module).get_config(slurm_id, "", "")
    if cfg.problem.gaussian_scale == "adaptive":
        cfg.network.rescale = 0.5 if cfg.problem.target in {"mnist", "cifar10", "celeb_a"} else 1.0
    
    sampler_fn = define_sampler(cfg)
    
    # Initialize network
    net, params, _ = (
        velocity.initialize_velocity
        if cfg.training.train_velocity else flow_map.initialize_flow_map
    )(cfg.network, jnp.zeros(cfg.problem.image_dims), jax.random.PRNGKey(SEED))
    
    # Load checkpoint
    with open(ckpt_path, "rb") as f:
        dummy_tx, _ = state_utils.setup_optimizer(cfg)
        ts = state_utils.EMATrainState.create(
            apply_fn=net.apply, params=params, ema_params={ema: params}, tx=dummy_tx
        )
        ts = flax.serialization.from_bytes(ts, f.read())
    
    params = ts.ema_params[ema] if ema else ts.params
    
    # Sample
    imgs = sampler_fn(net.apply, params, x0s, n_steps, None)
    imgs = ((jnp.clip(imgs, -1, 1).transpose(0, 2, 3, 1) + 1) / 2).astype(np.float32)
    return make_grid(np.asarray(imgs))

# ==================== Generate Samples ====================
@functools.partial(jax.jit, static_argnums=(0,))
def sample_rho0(bs, key):
    return 0.5 * jax.random.normal(key, (bs, 3, 64, 64))

key = jax.random.PRNGKey(SEED)
x0s = sample_rho0(N_SHOW, key)

# Sample and visualize for each method
for title, config in TITLE_TO_CONFIG.items():
    if title not in best_checkpoints:
        print(f"⚠️  No checkpoints found for {title}")
        continue
    
    print(f"\n{'='*60}\nSampling {config['label']}\n{'='*60}")
    
    grids = []
    for n in N_STEPS:
        if n not in best_checkpoints[title]:
            print(f"⚠️  No checkpoint for N={n}, skipping")
            continue
        
        best = best_checkpoints[title][n]
        ckpt_path = f"{model_folder}/{config['base_name']}_{best['checkpoint']}.pkl"
        
        print(f"N={n:2d}: Loading checkpoint {best['checkpoint']:3d} (FID={best['fid']:.3f})")
        
        grid = sample_single_n(
            ckpt_path, 
            best['ema'], 
            config['slurm_id'], 
            config['cfg_module'], 
            x0s, 
            n
        )
        grids.append(grid)
    
    # Create visualization
    n_rows = len(grids)
    fig, axes = plt.subplots(
        n_rows, 1,
        figsize=(N_SHOW*1.6, n_rows*1.6),
        dpi=160,
        tight_layout=True
    )
    if n_rows == 1:
        axes = [axes]
    
    for ax, grid, n in zip(axes, grids, N_STEPS[:len(grids)]):
        ax.imshow(grid)
        ax.set_xticks([]); ax.set_yticks([]); ax.set_xlabel("")
        for spine in ("top", "right", "bottom"):
            ax.spines[spine].set_visible(False)
    
    # Save
    out_name = f"celeba64_{config['label'].replace(' ', '_')}_best.png"
    fig.savefig(out_name, dpi=160, bbox_inches="tight")
    print(f"✓ Saved → {out_name}")
    plt.show()

print("\n✓ Done!")
# Out:
# Loaded 300 FID records
# Unique titles: ['fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed'
#  'fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed'
#  'fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed']
#
# LSD (fid_celeba_lsd_stopgrad_convex_diag75_bs256_9_8_resumed):
#   N= 1 → checkpoint 120, ema=0.9999, FID=12.224
#   N= 2 → checkpoint  65, ema=0.9999, FID=5.737
#   N= 4 → checkpoint 120, ema=0.9999, FID=3.181
#   N= 8 → checkpoint 120, ema=0.9999, FID=2.183
#   N=16 → checkpoint  95, ema=0.9999, FID=1.964
#
# PSD-M (fid_celeba_pfmm_shortcut_stopgrad_convex_diag75_bs256_9_8_resumed):
#   N= 1 → checkpoint  90, ema=0.9999, FID=19.641
#   N= 2 → checkpoint  85, ema=0.9999, FID=11.747
#   N= 4 → checkpoint 120, ema=0.9999, FID=7.891
#   N= 8 → checkpoint 120, ema=0.9999, FID=6.064
#   N=16 → checkpoint 120, ema=0.9999, FID=5.093
#
# PSD-U (fid_celeba_pfmm_uniform_stopgrad_convex_diag75_bs256_9_8_resumed):
#   N= 1 → checkpoint  85, ema=0.9999, FID=18.814
#   N= 2 → checkpoint  85, ema=0.9999, FID=11.023
#   N= 4 → checkpoint  85, ema=0.9999, FID=7.466
#   N= 8 → checkpoint  80, ema=0.9999, FID=5.997
#   N=16 → checkpoint 125, ema=0.9999, FID=5.627
#
# ============================================================
# Sampling LSD
# ============================================================
# N= 1: Loading checkpoint 120 (FID=12.224)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  65 (FID=5.737)
# Number of parameters: 124264485
# N= 4: Loading checkpoint 120 (FID=3.181)
# Number of parameters: 124264485
# N= 8: Loading checkpoint 120 (FID=2.183)
# Number of parameters: 124264485
# N=16: Loading checkpoint  95 (FID=1.964)
# Number of parameters: 124264485
# ✓ Saved → celeba64_LSD_best.png
# ============================================================
# Sampling PSD-M
# ============================================================
# N= 1: Loading checkpoint  90 (FID=19.641)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  85 (FID=11.747)
# Number of parameters: 124264485
# N= 4: Loading checkpoint 120 (FID=7.891)
# Number of parameters: 124264485
# N= 8: Loading checkpoint 120 (FID=6.064)
# Number of parameters: 124264485
# N=16: Loading checkpoint 120 (FID=5.093)
# Number of parameters: 124264485
# ✓ Saved → celeba64_PSD-M_best.png
# ============================================================
# Sampling PSD-U
# ============================================================
# N= 1: Loading checkpoint  85 (FID=18.814)
# Number of parameters: 124264485
# N= 2: Loading checkpoint  85 (FID=11.023)
# Number of parameters: 124264485
# N= 4: Loading checkpoint  85 (FID=7.466)
# Number of parameters: 124264485
# N= 8: Loading checkpoint  80 (FID=5.997)
# Number of parameters: 124264485
# N=16: Loading checkpoint 125 (FID=5.627)
# Number of parameters: 124264485
# ✓ Saved → celeba64_PSD-U_best.png
# ✓ Done!
